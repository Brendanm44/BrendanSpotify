# %%
import numpy as np
import scipy as sp
import scipy.spatial.distance as spd
import scipy.cluster.hierarchy as sph
import sklearn as sk
import sklearn.cluster as skc
import sklearn.metrics as skm
import pandas as pd
import matplotlib.pyplot as plt

# %%
bdan_library = pd.read_csv("Brendan Listening Data.csv")

# %%
list(bdan_library)
# Out:
# ['Track URI',
#  'Track Name',
#  'Artist URI',
#  'Artist Name',
#  'Album URI',
#  'Album Name',
#  'Album Release Date',
#  'Album Image URL',
#  'Disc Number',
#  'Track Number',
#  'Track Duration (ms)',
#  'Track Preview URL',
#  'Explicit',
#  'Popularity',
#  'Added By',
#  'Added At',
#  'Artist Genres',
#  'Danceability',
#  'Energy',
#  'Key',
#  'Loudness',
#  'Mode',
#  'Speechiness',
#  'Acousticness',
#  'Instrumentalness',
#  'Liveness',
#  'Valence',
#  'Tempo',
#  'Time Signature']

# %%
#Drop all unneccesary columns:

bdan_library.drop(['Track URI', 'Artist URI', 'Album URI', 'Album Image URL', 'Disc Number', 'Track Number', 'Track Preview URL', 'Added By'], axis = 1, inplace = True)

# %%
#Sort the data by artist

bdan_library.sort_values(by=['Artist Name'], inplace = True)

# %%
bdan_library.head()
# Out:
#                    Track Name  Artist Name                Album Name  \
# 2940  Either Hated Or Ignored  $uicideBoy$   Either Hated Or Ignored
# 2043                     Rude    03 Greedo  The Wolf of Grape Street
# 2726               Never Bend    03 Greedo  Money Changes Everything
# 2729                   Pop It    03 Greedo  The Wolf of Grape Street
# 2731       Prayer For My Lost    03 Greedo                 God Level
#
#      Album Release Date  Track Duration (ms)  Explicit  Popularity  \
# 2940         2018-04-13               153782      True          61
# 2043         2018-03-09               154105      True          49
# 2726         2017-07-04               193270      True           0
# 2729         2018-03-09               177777      True          25
# 2731         2018-06-27               264829      True          21
#
#                   Added At                                      Artist Genres  \
# ...

# %%
bdan_library.groupby("Artist Name").count()
# Out:
#                   Track Name  Album Name  Album Release Date  \
# Artist Name
# $uicideBoy$                1           1                   1
# 03 Greedo                  7           7                   7
# 03 Greedo, AD              1           1                   1
# 070 Shake                  1           1                   1
# 100 gecs                   5           5                   5
# ...                      ...         ...                 ...
# sports.                    1           1                   1
# toe                        2           2                   2
# tomemitsu                  1           1                   1
# Труд                       1           1                   1
# 박혜진 Park Hye Jin           2           2                   2
#
#                   Track Duration (ms)  Explicit  Popularity  Added At  \
# Artist Name
# $uicideBoy$                         1         1           1         1
# ...

# %%
#Export to CSV:

bdan_library.to_csv('Brendan_Library_Cleaned.csv')

# %% [markdown]
# # Take 2 With Filtered Data From Tableau

# %%
bdan_toplib = pd.read_csv('Top_Artists_(Appear 5 Times in Library).csv')

# %%
bdan_toplib.drop(['Track URI', 'Artist URI', 'Album URI', 'Album Image URL', 'Disc Number', 'Track Number', 'Track Preview URL', 'Added By'], axis = 1, inplace = True)

# %%
bdan_toplib.sort_values(by=['Artist Name'], inplace = True)

# %%
bdan_toplib.head()
# Out:
#      Artist Name                Added At                Album Name  \
# 1062   03 Greedo  2018-08-01 10:57:20 PM  The Wolf of Grape Street
# 1178   03 Greedo   2018-07-31 8:22:42 PM                 God Level
# 3164   03 Greedo   2018-07-31 7:52:37 PM                 God Level
# 3206   03 Greedo   2018-07-31 7:56:28 PM                 God Level
# 1155   03 Greedo  2019-02-08 12:05:01 AM  The Wolf of Grape Street
#
#      Album Release Date                                      Artist Genres  \
# 1062         2018-03-09  cali rap,melodic rap,trap,underground hip hop,...
# 1178         2018-06-27  cali rap,melodic rap,trap,underground hip hop,...
# 3164         2018-06-27  cali rap,melodic rap,trap,underground hip hop,...
# 3206         2018-06-27  cali rap,melodic rap,trap,underground hip hop,...
# 1155         2018-03-09  cali rap,melodic rap,trap,underground hip hop,...
#
#       Explicit  Key          Track Name  Acousticness  Danceability  ...  \
# ...

# %%
#Only main artist (removes collaborations features common in hip hop songs for example)

bdan_toplib['Artist'] = bdan_toplib['Artist Name'].str.split(',').str[0]

# %%
bdan_toplib['Artist'].unique()
# Out:
# array(['03 Greedo', '100 gecs', '1010 Benja SL', '18+', '21 Savage',
#        'A Tribe Called Quest', 'Acetone', 'Adrianne Lenker',
#        'Against All Logic', 'Alex G', 'Algernon Cadwallader', 'Alvvays',
#        'America', 'American Football', 'American Wrestlers',
#        'Amnesia Scanner', 'Andy Shauf', 'Angel Olsen',
#        'Animal Collective', 'Antwon', 'Arca', 'Ariel Pink',
#        'Astral Swans', 'BA Johnston', 'BROCKHAMPTON', 'Balkans', 'Baths',
#        'Beach House', 'Beach Slang', 'Bedbug', 'Bent Denim', 'Bernice',
#        'Beyoncé', 'Big Thief', 'Black Belt Eagle Scout', 'Black Marble',
#        'Boards of Canada', 'Bonnie Prince Billy', 'Boy Scouts',
#        'Boyscott', "Brandon Can't Dance", 'Bruce Springsteen', 'Brutus',
#        'Bully', "Cap'n Jazz", 'Caribou', 'Caroline Rose', 'Caroline Says',
#        'Cass McCombs', 'Chad VanGaalen', 'Charli XCX', 'Chastity',
#        'Chastity Belt', 'Chin Up Chin Up', 'Chinese Football',
# ...

# %%
bdan_toplib.tail()
# Out:
#      Artist Name                Added At                   Album Name  \
# 1260    slowthai   2019-11-07 9:19:04 PM  Nothing Great About Britain
# 2916    slowthai  2019-12-06 10:55:49 PM  Nothing Great About Britain
# 3008    slowthai   2019-11-07 9:23:06 PM  Nothing Great About Britain
# 238     slowthai   2020-05-11 8:29:52 AM                        ENEMY
# 2977    slowthai  2019-11-07 10:25:03 PM  Nothing Great About Britain
#
#      Album Release Date                                      Artist Genres  \
# 1260         2019-05-17  hip hop,rap,uk alternative hip hop,uk hip hop,...
# 2916         2019-05-17  hip hop,rap,uk alternative hip hop,uk hip hop,...
# 3008         2019-05-17  hip hop,rap,uk alternative hip hop,uk hip hop,...
# 238          2020-05-10  hip hop,rap,uk alternative hip hop,uk hip hop,...
# 2977         2019-05-17  hip hop,rap,uk alternative hip hop,uk hip hop,...
#
#       Explicit  Key    Track Name  Acousticness  Danceability  ...  Liveness  \
# ...

# %%
bdan_toplib.to_csv('Brendan_Library_Cleaned_Top.csv')
